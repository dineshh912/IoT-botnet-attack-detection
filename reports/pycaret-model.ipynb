# %%
# Importing necssary modules
import pandas as pd
from datetime import datetime
from scripts.utils import load_data, load_data_multi_label, load_data_all

# %%
# Data folder path and Extention of the data files
base_directory = '../rawdata'
file_extension = "*.csv"

# %%
danmini_doorbell_df = load_data(base_directory, file_extension, 'Danmini_Doorbell')

# %%
danmini_doorbell_df.shape
# Out:
# (1018298, 117)

# %%
df = danmini_doorbell_df.sample(frac=0.3)

# %%
df.shape
# Out:
# (305489, 117)

# %%
# check version
from pycaret.utils import version
version()
# Out:
# '2.1.2'

# %%
from pycaret.classification import *

# %%
clf1 = setup(df, target = 'label', session_id=123, experiment_name='doorbell-1')
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_c6c103fa_0dd7_11eb_8aa6_0897987917c6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c6c103fa_0dd7_11eb_8aa6_0897987917c6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c6c103fa_0dd7_11eb_8aa6_0897987917c6row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_c6c103fa_0dd7_11eb_8aa6_0897987917c6row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_c6c103fa_0dd7_11eb_8aa6_0897987917c6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c6c103fa_0dd7_11eb_8aa6_0897987917c6row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
best_model = compare_models()
# Out:
# IntProgress(value=0, description='Processing: ', max=176)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          11:21:37
# Status     . . . . . . . . . . . . . . . . . .  Finalizing Model
# ETC        . . . . . . . . . . . . . . . . . .   Almost Finished
#                              Model  Accuracy  AUC  Recall   Prec.      F1  \
# 0         Random Forest Classifier    1.0000  0.0  0.9999  1.0000  1.0000
# 1         Decision Tree Classifier    0.9998  0.0  0.9997  0.9998  0.9998
# 2           K Neighbors Classifier    0.9980  0.0  0.9935  0.9980  0.9980
# 3                 Ridge Classifier    0.9969  0.0  0.9958  0.9969  0.9969
# 4             Ada Boost Classifier    0.9245  0.0  0.9202  0.9340  0.9216
# 5  Quadratic Discriminant Analysis    0.6834  0.0  0.8271  0.8491  0.6724
# 6                      Naive Bayes    0.6585  0.0  0.3543  0.7312  0.5410
# 7              SVM - Linear Kernel    0.4204  0.0  0.3930  0.4682  0.3959
# ...

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
#
#                                             Reference  Turbo
# ID
# lr            sklearn.linear_model.LogisticRegression   True
# ...

# %%
rf = create_model('rf', fold=5)
# Out:
# <style  type="text/css" >
# #T_892dfc8d_0ddf_11eb_ace8_0897987917c6row5_col0,#T_892dfc8d_0ddf_11eb_ace8_0897987917c6row5_col1,#T_892dfc8d_0ddf_11eb_ace8_0897987917c6row5_col2,#T_892dfc8d_0ddf_11eb_ace8_0897987917c6row5_col3,#T_892dfc8d_0ddf_11eb_ace8_0897987917c6row5_col4,#T_892dfc8d_0ddf_11eb_ace8_0897987917c6row5_col5,#T_892dfc8d_0ddf_11eb_ace8_0897987917c6row5_col6{
#             background:  yellow;
#         }</style><table id="T_892dfc8d_0ddf_11eb_ace8_0897987917c6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
dt = create_model('dt')
# Out:
# <style  type="text/css" >
# #T_1a06f9d9_0de0_11eb_944a_0897987917c6row10_col0,#T_1a06f9d9_0de0_11eb_944a_0897987917c6row10_col1,#T_1a06f9d9_0de0_11eb_944a_0897987917c6row10_col2,#T_1a06f9d9_0de0_11eb_944a_0897987917c6row10_col3,#T_1a06f9d9_0de0_11eb_944a_0897987917c6row10_col4,#T_1a06f9d9_0de0_11eb_944a_0897987917c6row10_col5,#T_1a06f9d9_0de0_11eb_944a_0897987917c6row10_col6{
#             background:  yellow;
#         }</style><table id="T_1a06f9d9_0de0_11eb_944a_0897987917c6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
tuned_rf = tune_model(rf)
# Out:
# <style  type="text/css" >
# #T_52a44e64_0de1_11eb_8ed0_0897987917c6row10_col0,#T_52a44e64_0de1_11eb_8ed0_0897987917c6row10_col1,#T_52a44e64_0de1_11eb_8ed0_0897987917c6row10_col2,#T_52a44e64_0de1_11eb_8ed0_0897987917c6row10_col3,#T_52a44e64_0de1_11eb_8ed0_0897987917c6row10_col4,#T_52a44e64_0de1_11eb_8ed0_0897987917c6row10_col5,#T_52a44e64_0de1_11eb_8ed0_0897987917c6row10_col6{
#             background:  yellow;
#         }</style><table id="T_52a44e64_0de1_11eb_8ed0_0897987917c6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
tuned_dt = tune_model(dt)
# Out:
# <style  type="text/css" >
# #T_ac7b76ee_0de1_11eb_944b_0897987917c6row10_col0,#T_ac7b76ee_0de1_11eb_944b_0897987917c6row10_col1,#T_ac7b76ee_0de1_11eb_944b_0897987917c6row10_col2,#T_ac7b76ee_0de1_11eb_944b_0897987917c6row10_col3,#T_ac7b76ee_0de1_11eb_944b_0897987917c6row10_col4,#T_ac7b76ee_0de1_11eb_944b_0897987917c6row10_col5,#T_ac7b76ee_0de1_11eb_944b_0897987917c6row10_col6{
#             background:  yellow;
#         }</style><table id="T_ac7b76ee_0de1_11eb_944b_0897987917c6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
evaluate_model(rf)
# Out:
#                          Parameters
# bootstrap                      True
# ccp_alpha                         0
# class_weight                   None
# criterion                      gini
# max_depth                      None
# max_features                   auto
# max_leaf_nodes                 None
# max_samples                    None
# min_impurity_decrease             0
# min_impurity_split             None
# min_samples_leaf                  1
# min_samples_split                 2
# min_weight_fraction_leaf          0
# n_estimators                     10
# n_jobs                           -1
# oob_score                     False
# random_state                    123
# verbose                           0
# warm_start                    False

# %%
evaluate_model(dt)
# Out:
#                           Parameters
# ccp_alpha                          0
# class_weight                    None
# criterion                       gini
# max_depth                       None
# max_features                    None
# max_leaf_nodes                  None
# min_impurity_decrease              0
# min_impurity_split              None
# min_samples_leaf                   1
# min_samples_split                  2
# min_weight_fraction_leaf           0
# presort                   deprecated
# random_state                     123
# splitter                        best
