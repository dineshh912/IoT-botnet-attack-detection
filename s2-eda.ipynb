# %%
# Importing necssary modules
import pandas as pd
import numpy as np
import seaborn as sns
import os
from scripts.utils import load_data

# %%
# Data folder path
base_directory = '../rawdata'
file_extension = "*.csv"

# %%
device_list = ['Danmini_Doorbell', 'Ecobee_Thermostat', 
                        'Ennio_Doorbell', 'Philips_B120N10_Baby_Monitor',
                        'Provision_PT_737E_Security_Camera', 'Provision_PT_838_Security_Camera',
                        'Samsung_SNH_1011_N_Webcam', 'SimpleHome_XCS7_1002_WHT_Security_Camera',
                        'SimpleHome_XCS7_1003_WHT_Security_Camera']

# %% [markdown]
# #### Danmini DoorBell

# %%
danmini_doorbell_df = load_data(base_directory, file_extension, 'Danmini_Doorbell')

# %%
danmini_doorbell_df.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1          1.000000      354.000000            0.000000          1.000000
# 2          1.857879      360.458980           35.789338          1.912127
# 3          1.000000      337.000000            0.000000          1.000000
# 4          1.680223      172.140917        18487.448750          1.793580
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1      354.000000            0.000000          1.000000      354.000000
# 2      360.275733           35.923972          1.969807      360.091968
# 3      337.000000            0.000000          1.000000      337.000000
# 4      182.560279        18928.175300          1.925828      193.165753
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_pcc  \
# 0            0.000000            1.000000  ...            0.0
# 1            0.000000            1.000000  ...            0.0
# 2           35.991542            1.996939  ...            0.0
# 3            0.000000            1.000000  ...            0.0
# 4        19153.795810            1.992323  ...            0.0
#
#    HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# 0           1.000000        60.000000        0.000000             60.000000
# 1           5.319895       344.262695        4.710446            344.262695
# 2           6.318264       347.703087        9.034660            347.703087
# 3           1.000000       337.000000        0.000000            337.000000
# 4           1.000000        60.000000        0.000000             60.000000
#
#    HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc   label  \
# 0           0.000000                    0.0             0.0  benign
# 1          22.188299                    0.0             0.0  benign
# 2          81.625077                    0.0             0.0  benign
# 3           0.000000                    0.0             0.0  benign
# 4           0.000000                    0.0             0.0  benign
#
#              device
# 0  Danmini_Doorbell
# 1  Danmini_Doorbell
# 2  Danmini_Doorbell
# 3  Danmini_Doorbell
# 4  Danmini_Doorbell
#
# [5 rows x 117 columns]

# %%
danmini_doorbell_df.shape
# Out:
# (1018298, 117)

# %%
danmini_doorbell_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018298 entries, 0 to 1018297
# Columns: 117 entries, MI_dir_L5_weight to device
# dtypes: float64(115), object(2)
# memory usage: 909.0+ MB

# %%
danmini_doorbell_df.describe()
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# count      1.018298e+06    1.018298e+06        1.018298e+06      1.018298e+06
# mean       9.479704e+01    1.927187e+02        1.970133e+04      1.502972e+02
# std        6.380090e+01    1.631548e+02        2.517558e+04      1.010881e+02
# min        1.000000e+00    6.000000e+01        0.000000e+00      1.000000e+00
# 25%        1.124271e+01    6.000000e+01        3.755417e-09      2.661462e+01
# 50%        1.108011e+02    7.407356e+01        3.869695e+01      1.870080e+02
# 75%        1.471055e+02    3.308499e+02        4.867314e+04      2.311400e+02
# max        3.416813e+02    8.861669e+02        1.738886e+05      4.704900e+02
#
#        MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# count    1.018298e+06        1.018298e+06      1.018298e+06    1.018298e+06
# mean     1.934838e+02        2.200175e+04      4.328257e+02    1.947330e+02
# std      1.565037e+02        2.676519e+04      2.933892e+02    1.525693e+02
# min      6.000000e+01        0.000000e+00      1.000000e+00    6.000000e+01
# 25%      6.000010e+01        3.010483e-05      8.697365e+01    6.000718e+01
# 50%      7.408601e+01        4.342837e+01      5.983945e+02    7.423949e+01
# 75%      3.470927e+02        5.360581e+04      6.589923e+02    3.664007e+02
# max      8.463203e+02        1.731848e+05      9.793564e+02    7.097253e+02
#
#        MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_radius  \
# count        1.018298e+06        1.018298e+06  ...      1.018298e+06
# mean         2.348970e+04        4.118614e+03  ...      2.403552e+01
# std          2.788289e+04        2.805190e+03  ...      2.098942e+03
# min          0.000000e+00        1.000000e+00  ...      0.000000e+00
# 25%          5.714647e-02        7.962799e+02  ...      0.000000e+00
# 50%          4.581586e+01        5.783836e+03  ...      0.000000e+00
# 75%          5.600682e+04        6.406809e+03  ...      0.000000e+00
# max          1.730770e+05        7.964172e+03  ...      4.340505e+05
#
#        HpHp_L0.1_covariance  HpHp_L0.1_pcc  HpHp_L0.01_weight  \
# count          1.018298e+06   1.018298e+06       1.018298e+06
# mean           3.218733e+00   8.169671e-05       7.405542e+02
# std            3.296057e+02   7.402182e-03       3.591651e+03
# min           -4.338246e+03  -5.414573e-01       1.000000e+00
# 25%            0.000000e+00   0.000000e+00       1.000000e+00
# 50%            0.000000e+00   0.000000e+00       1.000000e+00
# 75%            0.000000e+00   0.000000e+00       1.000000e+00
# max            6.036894e+04   9.560988e-01       2.344456e+04
#
#        HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# count     1.018298e+06    1.018298e+06          1.018298e+06
# mean      1.954142e+02    3.202275e-02          1.981046e+02
# std       2.166145e+02    2.090297e+00          2.158785e+02
# min       6.000000e+01    0.000000e+00          6.000000e+01
# 25%       6.000000e+01    0.000000e+00          6.000000e+01
# 50%       7.400000e+01    0.000000e+00          7.400000e+01
# 75%       5.540000e+02    0.000000e+00          5.540000e+02
# max       9.090000e+02    2.036722e+02          1.278265e+03
#
#        HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc
# count       1.018298e+06           1.018298e+06    1.018298e+06
# mean        3.669232e+01           8.477689e+00    1.980529e-04
# std         3.161461e+03           8.323430e+02    1.266375e-02
# min         0.000000e+00          -1.017176e+03   -5.416264e-01
# 25%         0.000000e+00           0.000000e+00    0.000000e+00
# 50%         0.000000e+00           0.000000e+00    0.000000e+00
# 75%         0.000000e+00           0.000000e+00    0.000000e+00
# max         4.793690e+05           1.365841e+05    1.531981e+00
#
# [8 rows x 115 columns]

# %% [markdown]
# #### Ecobee_Thermostat

# %%
ecobee_thermostat_df = load_data(base_directory, file_extension, 'Ecobee_Thermostat')

# %%
ecobee_thermostat_df.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1          1.000000      110.000000            0.000000          1.000000
# 2          1.724055       91.439104          249.441812          1.823878
# 3          1.000000      342.000000            0.000000          1.000000
# 4          2.516815       90.867308          150.827639          2.688981
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1      110.000000            0.000000          1.000000      110.000000
# 2       92.454965          253.612868          1.937463       93.483558
# 3      342.000000            0.000000          1.000000      342.000000
# 4       91.541993          160.705060          2.888469       92.277536
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_pcc  \
# 0            0.000000            1.000000  ...            0.0
# 1            0.000000            1.000000  ...            0.0
# 2          255.733288            1.993563  ...            0.0
# 3            0.000000            1.000000  ...            0.0
# 4          169.944112            2.988463  ...            0.0
#
#    HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# 0           1.000000        60.000000        0.000000             60.000000
# 1           1.238636       106.146795        7.887770            106.146795
# 2           1.000000        78.000000        0.000000             78.000000
# 3           2.487473       341.959189        7.347919            341.959189
# 4           2.237519        98.930412        9.942635             98.930412
#
#    HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc   label  \
# 0           0.000000                    0.0             0.0  benign
# 1          62.216910                    0.0             0.0  benign
# 2           0.000000                    0.0             0.0  benign
# 3          53.991908                    0.0             0.0  benign
# 4          98.855983                    0.0             0.0  benign
#
#               device
# 0  Ecobee_Thermostat
# 1  Ecobee_Thermostat
# 2  Ecobee_Thermostat
# 3  Ecobee_Thermostat
# 4  Ecobee_Thermostat
#
# [5 rows x 117 columns]

# %%
ecobee_thermostat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 835876 entries, 0 to 835875
# Columns: 117 entries, MI_dir_L5_weight to device
# dtypes: float64(115), object(2)
# memory usage: 746.1+ MB

# %%
ecobee_thermostat_df.shape
# Out:
# (835876, 117)

# %%
ecobee_thermostat_df.describe()
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# count     835876.000000   835876.000000        8.358760e+05     835876.000000
# mean          98.003402      220.472899        1.688949e+04        156.933719
# std           68.847613      187.861701        2.346392e+04        109.040422
# min            1.000000       60.000000        0.000000e+00          1.000000
# 25%            1.199515       60.000000        9.094947e-13          1.400636
# 50%          113.808087       74.044616        3.947754e+01        190.624152
# 75%          152.350429      405.213898        3.595471e+04        242.986523
# max          438.002839     1108.154953        2.721017e+05        505.805302
#
#        MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# count   835876.000000        8.358760e+05     835876.000000   835876.000000
# mean       220.131366        1.864839e+04        450.859739      219.641089
# std        182.895330        2.357280e+04        309.944529      177.919118
# min         60.000000        0.000000e+00          1.000000       60.000000
# 25%         60.000000        1.818989e-12          1.778399       60.000003
# 50%         74.060133        4.051358e+01        587.912980       74.117818
# 75%        410.900591        4.145993e+04        679.779763      419.401128
# max       1090.333261        2.693159e+05       1185.249664      940.451256
#
#        MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_radius  \
# count        8.358760e+05       835876.000000  ...     835876.000000
# mean         2.031539e+04         4201.866987  ...        339.208379
# std          2.379110e+04         2879.160682  ...       4856.512798
# min          0.000000e+00            1.000000  ...          0.000000
# 25%          6.173169e-07            3.026374  ...          0.000000
# 50%          4.074233e+01         5768.226428  ...          0.000000
# 75%          4.620504e+04         6453.703423  ...          0.000000
# max          2.416279e+05         8912.649148  ...     434050.471278
#
#        HpHp_L0.1_covariance  HpHp_L0.1_pcc  HpHp_L0.01_weight  \
# count         835876.000000  835876.000000      835876.000000
# mean             -30.647316      -0.001425        1493.051214
# std              741.067885       0.026193        5745.246986
# min           -40058.543210      -1.010724           1.000000
# 25%                0.000000       0.000000           1.000000
# 50%                0.000000       0.000000           1.000000
# 75%                0.000000       0.000000           1.000000
# max            60368.942049       0.956099       30006.660112
#
#        HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# count    835876.000000   835876.000000         835876.000000
# mean        218.800171        1.837398            221.329970
# std         227.155734       17.613690            227.571030
# min          60.000000        0.000000             60.000000
# 25%          60.000000        0.000000             60.000000
# 50%          74.000000        0.000000             74.000000
# 75%         554.000000        0.000000            554.000000
# max         909.000000      321.653614           1278.265351
#
#        HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc
# count      835876.000000          835876.000000   835876.000000
# mean          532.311720             -37.164277       -0.001349
# std          6386.956671            1163.711672        0.024598
# min             0.000000          -39463.345860       -0.690911
# 25%             0.000000               0.000000        0.000000
# 50%             0.000000               0.000000        0.000000
# 75%             0.000000               0.000000        0.000000
# max        479368.980762          136584.102023        1.531981
#
# [8 rows x 115 columns]

# %% [markdown]
# #### Ennio_Doorbell

# %%
ennio_doorbell_df = load_data(base_directory, file_extension, 'Ennio_Doorbell')

# %%
ennio_doorbell_df.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000             0.00000          1.000000
# 1          1.000000       70.000000             0.00000          1.000000
# 2          1.000023       89.999548             0.00904          1.001631
# 3          1.000000       60.000000             0.00000          1.000000
# 4          1.000000      590.000000             0.00000          1.000000
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000        0.000000e+00          1.000000       60.000000
# 1       70.000000        0.000000e+00          1.000000       70.000000
# 2       89.967432        6.503024e-01          1.117713       87.893685
# 3       60.000000        4.550000e-13          1.000091       60.000000
# 4      590.000000        0.000000e+00          1.000000      590.000000
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_pcc  \
# 0        0.000000e+00            1.000000  ...            0.0
# 1        0.000000e+00            1.000000  ...            0.0
# 2        3.768974e+01            1.807388  ...            0.0
# 3        4.550000e-13            1.394277  ...            0.0
# 4        0.000000e+00            1.000000  ...            0.0
#
#    HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# 0           1.000000        60.000000    0.000000e+00             60.000000
# 1           1.000000        70.000000    0.000000e+00             70.000000
# 2           1.000000        90.000000    0.000000e+00             90.000000
# 3           1.911130        60.000000    9.540000e-07             60.000000
# 4           4.274029       399.892026    1.050783e+02            399.892026
#
#    HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc   label  \
# 0       0.000000e+00                    0.0             0.0  benign
# 1       0.000000e+00                    0.0             0.0  benign
# 2       0.000000e+00                    0.0             0.0  benign
# 3       9.090000e-13                    0.0             0.0  benign
# 4       1.104145e+04                    0.0             0.0  benign
#
#            device
# 0  Ennio_Doorbell
# 1  Ennio_Doorbell
# 2  Ennio_Doorbell
# 3  Ennio_Doorbell
# 4  Ennio_Doorbell
#
# [5 rows x 117 columns]

# %%
ennio_doorbell_df.shape
# Out:
# (355500, 117)

# %%
ennio_doorbell_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 355500 entries, 0 to 355499
# Columns: 117 entries, MI_dir_L5_weight to device
# dtypes: float64(115), object(2)
# memory usage: 317.3+ MB

# %%
ennio_doorbell_df.describe()
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# count     355500.000000   355500.000000       355500.000000     355500.000000
# mean          42.917391       67.268125          266.961430         68.903479
# std           69.576572       15.958070         3048.519143        113.498429
# min            1.000000       60.000000            0.000000          1.000000
# 25%            1.000000       60.000000            0.000000          1.000000
# 50%            1.000000       60.000000            0.000000          1.000000
# 75%           71.470343       74.033009            0.527706        100.138669
# max          304.382099      886.166851       173888.566142        407.906734
#
#        MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# count   355500.000000       355500.000000     355500.000000   355500.000000
# mean        67.155625          292.858935        194.918780       67.112638
# std         14.056560         3073.339772        330.837382       12.154093
# min         60.000000            0.000000          1.000000       60.000000
# 25%         60.000000            0.000000          1.000000       60.000000
# 50%         60.000000            0.000000          1.000000       60.000000
# 75%         74.048391            1.042741        211.996467       74.068483
# max        846.320306       173184.843316        965.200154      709.725273
#
#        MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_radius  \
# count       355500.000000       355500.000000  ...     355500.000000
# mean           321.020962         1618.672220  ...         83.375737
# std           2731.241085         2836.533368  ...       3579.556268
# min              0.000000            1.000000  ...          0.000000
# 25%              0.000000            1.000000  ...          0.000000
# 50%              0.000000            1.000000  ...          0.000000
# 75%              3.756670         1102.904175  ...          0.000000
# max         173077.043447         7964.172032  ...     434050.471278
#
#        HpHp_L0.1_covariance  HpHp_L0.1_pcc  HpHp_L0.01_weight  \
# count         355500.000000  355500.000000      355500.000000
# mean               8.920656      -0.001510           1.534687
# std              557.073802       0.051064           3.913444
# min            -4338.246234      -1.116897           1.000000
# 25%                0.000000       0.000000           1.000000
# 50%                0.000000       0.000000           1.000000
# 75%                0.000000       0.000000           1.000000
# max            60368.942049       0.956099         135.246207
#
#        HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# count    355500.000000   355500.000000         355500.000000
# mean         67.487769        0.904566             71.710081
# std          24.152932        6.902255             35.610059
# min          60.000000        0.000000             60.000000
# 25%          60.000000        0.000000             60.000000
# 50%          60.000000        0.000000             60.000000
# 75%          74.000000        0.000000             74.000000
# max         909.000000      203.672181           1278.265351
#
#        HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc
# count      355500.000000          355500.000000   355500.000000
# mean          141.597236              23.554035       -0.011289
# std          5405.766408            1408.407031        0.087989
# min             0.000000           -1275.062598       -1.129921
# 25%             0.000000               0.000000        0.000000
# 50%             0.000000               0.000000        0.000000
# 75%             0.000000               0.000000        0.000000
# max        479368.980762          136584.102023        1.531981
#
# [8 rows x 115 columns]

# %% [markdown]
# #### Philips_B120N10_Baby_Monitor

# %%
baby_monitor_df = load_data(base_directory, file_extension, 'Philips_B120N10_Baby_Monitor')

# %%
baby_monitor_df.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000            60.0        0.000000e+00          1.000000
# 1          1.000000            60.0        0.000000e+00          1.000000
# 2          1.000000           342.0        0.000000e+00          1.000000
# 3          1.963325           342.0        4.370000e-11          1.977831
# 4          1.000000            60.0        0.000000e+00          1.000000
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0            60.0                 0.0          1.000000            60.0
# 1            60.0                 0.0          1.000000            60.0
# 2           342.0                 0.0          1.000000           342.0
# 3           342.0                 0.0          1.992555           342.0
# 4            60.0                 0.0          1.000000            60.0
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_pcc  \
# 0                 0.0            1.000000  ...            0.0
# 1                 0.0            1.000000  ...            0.0
# 2                 0.0            1.000000  ...            0.0
# 3                 0.0            1.999253  ...            0.0
# 4                 0.0            1.000000  ...            0.0
#
#    HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# 0           1.000000        60.000000        0.000000             60.000000
# 1           1.000000        60.000000        0.000000             60.000000
# 2           6.249414       449.603272      122.911136            449.603272
# 3           7.248947       434.759286      120.000074            434.759286
# 4           1.000000        60.000000        0.000000             60.000000
#
#    HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc   label  \
# 0            0.00000                    0.0             0.0  benign
# 1            0.00000                    0.0             0.0  benign
# 2        15107.14730                    0.0             0.0  benign
# 3        14400.01777                    0.0             0.0  benign
# 4            0.00000                    0.0             0.0  benign
#
#                          device
# 0  Philips_B120N10_Baby_Monitor
# 1  Philips_B120N10_Baby_Monitor
# 2  Philips_B120N10_Baby_Monitor
# 3  Philips_B120N10_Baby_Monitor
# 4  Philips_B120N10_Baby_Monitor
#
# [5 rows x 117 columns]

# %%
baby_monitor_df.shape
# Out:
# (1098677, 117)

# %%
baby_monitor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1098677 entries, 0 to 1098676
# Columns: 117 entries, MI_dir_L5_weight to device
# dtypes: float64(115), object(2)
# memory usage: 980.7+ MB

# %%
baby_monitor_df.describe()
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# count      1.098677e+06    1.098677e+06        1.098677e+06      1.098677e+06
# mean       8.282547e+01    1.760965e+02        1.744759e+04      1.311469e+02
# std        6.727041e+01    1.621744e+02        2.793956e+04      1.067120e+02
# min        1.000000e+00    6.000000e+01        0.000000e+00      1.000000e+00
# 25%        1.082647e+00    6.000018e+01        1.000000e-11      1.268566e+00
# 50%        1.020337e+02    7.309616e+01        1.501728e+01      1.703478e+02
# 75%        1.415139e+02    2.942596e+02        4.161710e+04      2.239025e+02
# max        3.416813e+02    1.452697e+03        4.756482e+05      4.704900e+02
#
#        MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# count    1.098677e+06        1.098677e+06      1.098677e+06    1.098677e+06
# mean     1.766500e+02        1.944151e+04      3.774167e+02    1.774775e+02
# std      1.560725e+02        2.941656e+04      3.098409e+02    1.520849e+02
# min      6.000000e+01        0.000000e+00      1.000000e+00    6.000000e+01
# 25%      6.000293e+01        2.525091e-06      2.010599e+00    6.002243e+01
# 50%      7.276055e+01        3.036599e+01      5.057184e+02    7.392377e+01
# 75%      3.235337e+02        4.915055e+04      6.513534e+02    3.578301e+02
# max      1.450730e+03        4.714568e+05      9.793564e+02    1.434056e+03
#
#        MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_radius  \
# count        1.098677e+06        1.098677e+06  ...      1.098677e+06
# mean         2.076965e+04        3.620586e+03  ...      1.524115e+03
# std          3.024090e+04        2.970856e+03  ...      2.250380e+04
# min          0.000000e+00        1.000000e+00  ...      0.000000e+00
# 25%          8.673721e-02        1.034542e+01  ...      0.000000e+00
# 50%          4.423586e+01        5.001760e+03  ...      0.000000e+00
# 75%          5.454683e+04        6.394434e+03  ...      0.000000e+00
# max          4.713175e+05        7.964172e+03  ...      5.014297e+05
#
#        HpHp_L0.1_covariance  HpHp_L0.1_pcc  HpHp_L0.01_weight  \
# count          1.098677e+06   1.098677e+06       1.098677e+06
# mean           3.969682e+01   7.607044e-04       6.804403e+02
# std            2.152637e+03   6.524347e-02       3.437138e+03
# min           -1.312975e+05  -1.586467e+00       1.000000e+00
# 25%            0.000000e+00   0.000000e+00       1.000000e+00
# 50%            0.000000e+00   0.000000e+00       1.000000e+00
# 75%            0.000000e+00   0.000000e+00       1.000000e+00
# max            1.309683e+05   1.949807e+00       2.338464e+04
#
#        HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# count     1.098677e+06    1.098677e+06          1.098677e+06
# mean      1.777278e+02    2.842404e+00          1.876841e+02
# std       2.080515e+02    2.067646e+01          2.085124e+02
# min       6.000000e+01    0.000000e+00          6.000000e+01
# 25%       6.000000e+01    0.000000e+00          6.000000e+01
# 50%       6.640571e+01    0.000000e+00          7.400000e+01
# 75%       8.938369e+01    0.000000e+00          1.235640e+02
# max       1.437326e+03    6.810012e+02          1.438842e+03
#
#        HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc
# count       1.098677e+06           1.098677e+06    1.098677e+06
# mean        2.251998e+03           6.165544e+01    9.553917e-03
# std         2.462753e+04           2.522841e+03    7.671229e-02
# min         0.000000e+00          -1.820963e+05   -1.732641e+00
# 25%         0.000000e+00           0.000000e+00    0.000000e+00
# 50%         0.000000e+00           0.000000e+00    0.000000e+00
# 75%         0.000000e+00           0.000000e+00    0.000000e+00
# max         4.793690e+05           1.365841e+05    1.953555e+00
#
# [8 rows x 115 columns]

# %% [markdown]
# #### Provision_PT_737E_Security_Camera

# %%
provision_cam1_df = load_data(base_directory, file_extension, 'Provision_PT_737E_Security_Camera')

# %%
provision_cam1_df.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1          1.000000      590.000000            0.000000          1.000000
# 2          1.942585      590.000000            0.000000          1.965145
# 3          1.000000       60.000000            0.000000          1.000000
# 4          1.979600       66.061831           35.996177          1.987709
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0         60.0000        0.000000e+00          1.000000       60.000000
# 1        590.0000        0.000000e+00          1.000000      590.000000
# 2        590.0000        1.160000e-10          1.988244      590.000000
# 3         60.0000        0.000000e+00          1.000000       60.000000
# 4         66.0371        3.599862e+01          1.995886       66.012367
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_pcc  \
# 0            0.000000            1.000000  ...            0.0
# 1            0.000000            1.000000  ...            0.0
# 2            0.000000            1.998818  ...            0.0
# 3            0.000000            1.000000  ...            0.0
# 4           35.999847            1.999588  ...            0.0
#
#    HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# 0           1.000000        60.000000        0.000000             60.000000
# 1           6.302352       416.121686      113.526005            416.121686
# 2           7.301607       439.935392      121.229684            439.935392
# 3           1.000000        60.000000        0.000000             60.000000
# 4           1.000000        72.000000        0.000000             72.000000
#
#    HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc   label  \
# 0            0.00000                    0.0             0.0  benign
# 1        12888.15384                    0.0             0.0  benign
# 2        14696.63622                    0.0             0.0  benign
# 3            0.00000                    0.0             0.0  benign
# 4            0.00000                    0.0             0.0  benign
#
#                               device
# 0  Provision_PT_737E_Security_Camera
# 1  Provision_PT_737E_Security_Camera
# 2  Provision_PT_737E_Security_Camera
# 3  Provision_PT_737E_Security_Camera
# 4  Provision_PT_737E_Security_Camera
#
# [5 rows x 117 columns]

# %%
provision_cam1_df.shape
# Out:
# (828260, 117)

# %%
provision_cam1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 828260 entries, 0 to 828259
# Columns: 117 entries, MI_dir_L5_weight to device
# dtypes: float64(115), object(2)
# memory usage: 739.3+ MB

# %%
provision_cam1_df.describe()
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# count     828260.000000   828260.000000       828260.000000     828260.000000
# mean          67.311679      154.571968        16721.765263        103.003649
# std           61.644950      140.697750        24611.124407         95.028445
# min            1.000000       60.000000            0.000000          1.000000
# 25%            1.000000       60.000000            0.000000          1.000000
# 50%           60.962622       74.006076            2.596261         95.806756
# 75%          109.076405      234.606146        44657.446837        159.868286
# max          379.917235      886.166851       410576.913200        558.677007
#
#        MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# count   828260.000000       828260.000000     828260.000000   828260.000000
# mean       154.717533        18538.776636        277.934433      155.128548
# std        134.218858        26255.495273        256.094264      128.004176
# min         60.000000            0.000000          1.000000       60.000000
# 25%         60.000000            0.000000          1.000000       60.000000
# 50%         74.015634            3.977276        261.573391       74.034819
# 75%        265.366024        52088.312604        413.999858      306.918157
# max        846.320306       302101.970400       1010.048007      709.725273
#
#        MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_radius  \
# count       828260.000000       828260.000000  ...     828260.000000
# mean         20275.652743         2450.751309  ...       1329.174271
# std          27989.989272         2185.002931  ...      15068.150321
# min              0.000000            1.000000  ...          0.000000
# 25%              0.000000            1.000000  ...          0.000000
# 50%             33.036999         2532.802127  ...          0.000000
# 75%          58414.947092         3822.592585  ...          0.000000
# max         173077.043447         7964.172032  ...     434050.471278
#
#        HpHp_L0.1_covariance  HpHp_L0.1_pcc  HpHp_L0.01_weight  \
# count         828260.000000  828260.000000      828260.000000
# mean             234.077816       0.003537         289.454279
# std             2692.664408       0.056623        1679.815577
# min           -27280.169700      -0.609781           1.000000
# 25%                0.000000       0.000000           1.000000
# 50%                0.000000       0.000000           1.000000
# 75%                0.000000       0.000000           1.000000
# max            60368.942049       0.966317       13321.876182
#
#        HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# count    828260.000000   828260.000000         828260.000000
# mean        155.506326        3.172875            159.110297
# std         189.858825       27.771809            190.917255
# min          60.000000        0.000000             60.000000
# 25%          60.000000        0.000000             60.000000
# 50%          60.000000        0.000000             60.000000
# 75%          74.000000        0.000000             95.268043
# max        1470.000000      417.683943           1470.000000
#
#        HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc
# count      828260.000000          828260.000000   828260.000000
# mean         1345.750905             240.837307        0.004218
# std         15296.174170            2825.419643        0.053942
# min             0.000000          -37939.452350       -0.966127
# 25%             0.000000               0.000000        0.000000
# 50%             0.000000               0.000000        0.000000
# 75%             0.000000               0.000000        0.000000
# max        479368.980762          136584.102023        1.531981
#
# [8 rows x 115 columns]

# %% [markdown]
# #### Provision_PT_838_Security_Camera

# %%
provision_cam2_df = load_data(base_directory, file_extension, 'Provision_PT_838_Security_Camera')

# %%
provision_cam2_df.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000        0.000000e+00          1.000000
# 1          1.000000      590.000000        0.000000e+00          1.000000
# 2          1.956973      590.000000        5.820000e-11          1.973957
# 3          1.000000       60.000000        0.000000e+00          1.000000
# 4          1.988608       66.034372        3.599882e+01          1.993149
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1      590.000000            0.000000          1.000000      590.000000
# 2      590.000000            0.000000          1.991242      590.000000
# 3       60.000000            0.000000          1.000000       60.000000
# 4       66.020623           35.999575          1.997711       66.006874
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_pcc  \
# 0            0.000000            1.000000  ...            0.0
# 1            0.000000            1.000000  ...            0.0
# 2            0.000000            1.999121  ...            0.0
# 3            0.000000            1.000000  ...            0.0
# 4           35.999953            1.999771  ...            0.0
#
#    HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# 0           1.000000        60.000000        0.000000             60.000000
# 1           4.456899       443.197258      121.885335            443.197258
# 2           5.456507       470.101420      123.932152            470.101420
# 3           1.000000        60.000000        0.000000             60.000000
# 4           1.000000        72.000000        0.000000             72.000000
#
#    HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc   label  \
# 0            0.00000                    0.0             0.0  benign
# 1        14856.03496                    0.0             0.0  benign
# 2        15359.17835                    0.0             0.0  benign
# 3            0.00000                    0.0             0.0  benign
# 4            0.00000                    0.0             0.0  benign
#
#                              device
# 0  Provision_PT_838_Security_Camera
# 1  Provision_PT_838_Security_Camera
# 2  Provision_PT_838_Security_Camera
# 3  Provision_PT_838_Security_Camera
# 4  Provision_PT_838_Security_Camera
#
# [5 rows x 117 columns]

# %%
provision_cam2_df.shape
# Out:
# (836891, 117)

# %%
provision_cam2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 836891 entries, 0 to 836890
# Columns: 117 entries, MI_dir_L5_weight to device
# dtypes: float64(115), object(2)
# memory usage: 747.0+ MB

# %%
provision_cam2_df.describe()
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# count     836891.000000   836891.000000        8.368910e+05     836891.000000
# mean          64.946298      154.473108        1.701537e+04         99.210173
# std           61.104935      139.099314        2.478295e+04         94.222388
# min            1.000000       60.000000        0.000000e+00          1.000000
# 25%            1.000000       60.000012        9.090000e-13          1.000075
# 50%           57.598617       74.009565        3.527870e+00         91.151448
# 75%          106.046318      230.491678        4.486814e+04        155.406179
# max          379.917235      895.336451        4.918058e+05        558.677007
#
#        MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# count   836891.000000        8.368910e+05     836891.000000   836891.000000
# mean       154.608027        1.881234e+04        267.718525      155.166447
# std        132.606058        2.633546e+04        254.815284      126.335761
# min         60.000000        0.000000e+00          1.000000       60.000000
# 25%         60.001397        7.190000e-11          1.078198       60.038167
# 50%         74.022095        6.916558e+00        248.028368       74.045487
# 75%        261.872004        5.216798e+04        407.026244      305.271495
# max        846.320306        4.645006e+05       1010.048007      709.725273
#
#        MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_radius  \
# count       836891.000000       836891.000000  ...     836891.000000
# mean         20638.298303         2388.485119  ...       3252.656649
# std          27923.522620         2186.780230  ...      26847.757173
# min              0.000000            1.000000  ...          0.000000
# 25%              0.035987            3.465036  ...          0.000000
# 50%             43.364366         2088.574969  ...          0.000000
# 75%          58333.382663         3813.098547  ...          0.000000
# max         179966.158000         7964.172032  ...     434050.471278
#
#        HpHp_L0.1_covariance  HpHp_L0.1_pcc  HpHp_L0.01_weight  \
# count         836891.000000  836891.000000      836891.000000
# mean             500.257952       0.010029         280.659798
# std             4063.604969       0.084271        1651.895534
# min           -29473.033130      -0.781090           1.000000
# 25%                0.000000       0.000000           1.000000
# 50%                0.000000       0.000000           1.000000
# 75%                0.000000       0.000000           1.000000
# max            93411.123880       1.133938       13202.853996
#
#        HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# count    836891.000000   836891.000000         836891.000000
# mean        155.769027        6.008762            161.562982
# std         188.120107       39.188987            191.443586
# min          60.000000        0.000000             60.000000
# 25%          60.000000        0.000000             60.000000
# 50%          60.000000        0.000000             60.000000
# 75%          74.000000        0.000000             95.268043
# max        1470.000000      420.542730           1470.000000
#
#        HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc
# count      836891.000000          836891.000000   836891.000000
# mean         3269.810791             507.434492        0.010345
# std         26975.159323            4153.363252        0.083678
# min             0.000000          -18695.932100       -0.972119
# 25%             0.000000               0.000000        0.000000
# 50%             0.000000               0.000000        0.000000
# 75%             0.000000               0.000000        0.000000
# max        479368.980762          136584.102023        1.531981
#
# [8 rows x 115 columns]

# %% [markdown]
# #### Samsung_SNH_1011_N_Webcam

# %%
samsung_cam_df = load_data(base_directory, file_extension, 'Samsung_SNH_1011_N_Webcam')

# %%
samsung_cam_df.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1          1.000000       70.000000            0.000000          1.000000
# 2          1.000008       89.999836            0.003289          1.000889
# 3          1.000000      322.000000            0.000000          1.000000
# 4          1.784845      328.723273           35.476876          1.864710
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1       70.000000            0.000000          1.000000       70.000000
# 2       89.982231            0.355061          1.096162       88.245473
# 3      322.000000            0.000000          1.000000      322.000000
# 4      328.435318           35.810498          1.952701      328.145333
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_pcc  \
# 0            0.000000            1.000000  ...            0.0
# 1            0.000000            1.000000  ...            0.0
# 2           32.012169            1.791226  ...            0.0
# 3            0.000000            1.000000  ...            0.0
# 4           35.978878            1.995166  ...            0.0
#
#    HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# 0           1.000000        60.000000        0.000000             60.000000
# 1           1.000000        70.000000        0.000000             70.000000
# 2           1.000000        90.000000        0.000000             90.000000
# 3          11.163562       380.087760       92.127549            380.087760
# 4          12.158154       376.297073       89.161260            376.297073
#
#    HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc   label  \
# 0           0.000000                    0.0             0.0  benign
# 1           0.000000                    0.0             0.0  benign
# 2           0.000000                    0.0             0.0  benign
# 3        8487.485312                    0.0             0.0  benign
# 4        7949.730316                    0.0             0.0  benign
#
#                       device
# 0  Samsung_SNH_1011_N_Webcam
# 1  Samsung_SNH_1011_N_Webcam
# 2  Samsung_SNH_1011_N_Webcam
# 3  Samsung_SNH_1011_N_Webcam
# 4  Samsung_SNH_1011_N_Webcam
#
# [5 rows x 117 columns]

# %%
samsung_cam_df.shape
# Out:
# (375222, 117)

# %%
samsung_cam_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375222 entries, 0 to 375221
# Columns: 117 entries, MI_dir_L5_weight to device
# dtypes: float64(115), object(2)
# memory usage: 334.9+ MB

# %%
samsung_cam_df.describe()
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# count     375222.000000   375222.000000       375222.000000     375222.000000
# mean          42.389824       94.741520          547.358505         68.157185
# std           69.411217       95.291387         5478.276281        113.293856
# min            1.000000       60.000000            0.000000          1.000000
# 25%            1.000000       60.000000            0.000000          1.000000
# 50%            1.000000       60.000000            0.000000          1.000000
# 75%           67.525377       74.066985            1.279527         95.708905
# max          304.382099     1187.194258       474036.374100        407.906734
#
#        MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# count   375222.000000       375222.000000     375222.000000   375222.000000
# mean        94.998401          688.273526        193.302671       95.378641
# std         94.697453         5803.109292        330.605616       92.817429
# min         60.000000            0.000000          1.000000       60.000000
# 25%         60.000000            0.000000          1.000000       60.000000
# 50%         60.000000            0.000000          1.000000       60.000000
# 75%         74.080917            1.935877        203.359977       74.216846
# max       1093.288379       478981.591600        965.200154      884.415886
#
#        MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_radius  \
# count       375222.000000       375222.000000  ...     375222.000000
# mean          1105.496064         1595.765963  ...        768.589208
# std           6443.565835         2826.452151  ...      12019.039208
# min              0.000000            1.000000  ...          0.000000
# 25%              0.000000            1.000000  ...          0.000000
# 50%              0.000000            1.000000  ...          0.000000
# 75%             22.414420         1087.690492  ...          0.000000
# max         479417.226900         7964.172032  ...     434050.471278
#
#        HpHp_L0.1_covariance  HpHp_L0.1_pcc  HpHp_L0.01_weight  \
# count         375222.000000  375222.000000      375222.000000
# mean              22.099331       0.001160           4.063444
# std             1231.716577       0.030412          21.826001
# min           -46276.247370      -0.723972           1.000000
# 25%                0.000000       0.000000           1.000000
# 50%                0.000000       0.000000           1.000000
# 75%                0.000000       0.000000           1.678887
# max           140609.414400       1.063518         402.363217
#
#        HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# count    375222.000000   375222.000000         375222.000000
# mean         94.929787        5.532047            103.447059
# std          98.134751       22.221617            108.841661
# min          60.000000        0.000000             60.000000
# 25%          60.000000        0.000000             60.000000
# 50%          60.000000        0.000000             60.000000
# 75%          74.000000        0.000000             74.000000
# max         909.000000      418.626612           1278.265351
#
#        HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc
# count      375222.000000          375222.000000   375222.000000
# mean         1083.614672              39.262109        0.001361
# std         13420.342485            1679.541476        0.029586
# min             0.000000          -43051.104220       -0.789555
# 25%             0.000000               0.000000        0.000000
# 50%             0.000000               0.000000        0.000000
# 75%             0.000000               0.000000        0.000000
# max        479368.980762          136584.102023        1.531981
#
# [8 rows x 115 columns]

# %% [markdown]
# #### SimpleHome_XCS7_1002_WHT_Security_Camera

# %%
simplehome_cam1_df = load_data(base_directory, file_extension, 'SimpleHome_XCS7_1002_WHT_Security_Camera')

# %%
simplehome_cam1_df.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1          1.000000      322.000000            0.000000          1.000000
# 2          1.920484      328.248423           35.938286          1.951502
# 3          1.000000       60.000000            0.000000          1.000000
# 4          1.973903       71.145433          120.978849          1.984259
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1      322.000000            0.000000          1.000000      322.000000
# 2      328.149109           35.977767          1.983566      328.049712
# 3       60.000000            0.000000          1.000000       60.000000
# 4       71.087263          120.992385          1.994725       71.029088
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_pcc  \
# 0            0.000000            1.000000  ...            0.0
# 1            0.000000            1.000000  ...            0.0
# 2           35.997529            1.998344  ...            0.0
# 3            0.000000            1.000000  ...            0.0
# 4          120.999154            1.999471  ...            0.0
#
#    HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# 0           1.000000        60.000000        0.000000             60.000000
# 1           6.087070       338.794642        8.566964            338.794642
# 2           7.086062       338.118012        8.113068            338.118012
# 3           1.000000        60.000000        0.000000             60.000000
# 4           1.000000        82.000000        0.000000             82.000000
#
#    HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc   label  \
# 0           0.000000                    0.0             0.0  benign
# 1          73.392866                    0.0             0.0  benign
# 2          65.821880                    0.0             0.0  benign
# 3           0.000000                    0.0             0.0  benign
# 4           0.000000                    0.0             0.0  benign
#
#                                      device
# 0  SimpleHome_XCS7_1002_WHT_Security_Camera
# 1  SimpleHome_XCS7_1002_WHT_Security_Camera
# 2  SimpleHome_XCS7_1002_WHT_Security_Camera
# 3  SimpleHome_XCS7_1002_WHT_Security_Camera
# 4  SimpleHome_XCS7_1002_WHT_Security_Camera
#
# [5 rows x 117 columns]

# %%
simplehome_cam1_df.shape
# Out:
# (863056, 117)

# %%
simplehome_cam1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 863056 entries, 0 to 863055
# Columns: 117 entries, MI_dir_L5_weight to device
# dtypes: float64(115), object(2)
# memory usage: 770.4+ MB

# %%
simplehome_cam1_df.describe()
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# count     863056.000000   863056.000000        8.630560e+05     863056.000000
# mean          95.647599      215.822009        1.576868e+04        153.065158
# std           69.929327      185.181123        2.302820e+04        110.960855
# min            1.000000       60.000000        0.000000e+00          1.000000
# 25%            1.032189       60.000001        1.364242e-12          1.142643
# 50%          111.713037       74.049939        3.105711e+01        187.692294
# 75%          151.735929      393.493750        3.174771e+04        242.323014
# max          438.002839      886.166851        1.738886e+05        505.805302
#
#        MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# count   863056.000000        8.630560e+05     863056.000000   863056.000000
# mean       215.393688        1.740037e+04        439.868921      214.878229
# std        180.505463        2.318532e+04        316.324591      175.706675
# min         60.000000        0.000000e+00          1.000000       60.000000
# 25%         60.000098        3.183231e-12          1.955128       60.010396
# 50%         74.064982        3.599443e+01        584.147521       74.191607
# 75%        403.799765        3.888327e+04        679.943923      417.149695
# max        846.320306        1.731848e+05       1185.249664      709.725273
#
#        MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_radius  \
# count       863056.000000       863056.000000  ...     863056.000000
# mean         18982.535719         4120.633414  ...        353.147469
# std          23421.098914         2949.600013  ...       8307.891026
# min              0.000000            1.000000  ...          0.000000
# 25%              0.032617            3.519623  ...          0.000000
# 50%             39.897993         5756.239507  ...          0.000000
# 75%          45279.469082         6459.880782  ...          0.000000
# max         173077.043447         8946.997229  ...     449993.496000
#
#        HpHp_L0.1_covariance  HpHp_L0.1_pcc  HpHp_L0.01_weight  \
# count         863056.000000  863056.000000      863056.000000
# mean              -5.269121       0.002363        1287.925950
# std             1048.514787       0.066359        5284.172821
# min           -49771.565780      -0.814774           1.000000
# 25%                0.000000       0.000000           1.000000
# 50%                0.000000       0.000000           1.000000
# 75%                0.000000       0.000000           1.000000
# max            70451.460160       2.760701       29932.352278
#
#        HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# count    863056.000000   863056.000000         863056.000000
# mean        214.435111        0.385948            220.120213
# std         223.012803        7.832039            226.893005
# min          60.000000        0.000000             60.000000
# 25%          60.000000        0.000000             60.000000
# 50%          74.000000        0.000000             74.000000
# 75%         554.000000        0.000000            554.000000
# max         909.000000      221.450381           1278.265351
#
#        HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc
# count      863056.000000          863056.000000   863056.000000
# mean          524.875244               3.505060        0.002653
# std         12431.677455            2491.677525        0.072353
# min             0.000000          -69585.300930       -2.252107
# 25%             0.000000               0.000000        0.000000
# 50%             0.000000               0.000000        0.000000
# 75%             0.000000               0.000000        0.000000
# max        480237.044800          136584.102023        2.811226
#
# [8 rows x 115 columns]

# %% [markdown]
# #### SimpleHome_XCS7_1003_WHT_Security_Camera

# %%
simplehome_cam2_df = load_data(base_directory, file_extension, 'SimpleHome_XCS7_1003_WHT_Security_Camera')

# %%
simplehome_cam2_df.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000            60.0                 0.0          1.000000
# 1          1.000000            60.0                 0.0          1.000000
# 2          1.000000            60.0                 0.0          1.000000
# 3          1.000000           590.0                 0.0          1.000000
# 4          1.927179           590.0                 0.0          1.955648
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0            60.0                 0.0          1.000000            60.0
# 1            60.0                 0.0          1.000000            60.0
# 2            60.0                 0.0          1.000000            60.0
# 3           590.0                 0.0          1.000000           590.0
# 4           590.0                 0.0          1.984992           590.0
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_pcc  \
# 0                 0.0            1.000000  ...            0.0
# 1                 0.0            1.000000  ...            0.0
# 2                 0.0            1.000000  ...            0.0
# 3                 0.0            1.000000  ...            0.0
# 4                 0.0            1.998489  ...            0.0
#
#    HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# 0           1.000000        60.000000    0.000000e+00             60.000000
# 1           1.061357        60.000000    9.540000e-07             60.000000
# 2           1.000000        60.000000    0.000000e+00             60.000000
# 3           5.832783       388.850426    9.199164e+01            388.850426
# 4           6.831901       418.293119    1.108120e+02            418.293119
#
#    HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc   label  \
# 0       0.000000e+00                    0.0             0.0  benign
# 1       9.090000e-13                    0.0             0.0  benign
# 2       0.000000e+00                    0.0             0.0  benign
# 3       8.462461e+03                    0.0             0.0  benign
# 4       1.227931e+04                    0.0             0.0  benign
#
#                                      device
# 0  SimpleHome_XCS7_1003_WHT_Security_Camera
# 1  SimpleHome_XCS7_1003_WHT_Security_Camera
# 2  SimpleHome_XCS7_1003_WHT_Security_Camera
# 3  SimpleHome_XCS7_1003_WHT_Security_Camera
# 4  SimpleHome_XCS7_1003_WHT_Security_Camera
#
# [5 rows x 117 columns]

# %%
simplehome_cam2_df.shape
# Out:
# (850826, 117)

# %%
simplehome_cam2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850826 entries, 0 to 850825
# Columns: 117 entries, MI_dir_L5_weight to device
# dtypes: float64(115), object(2)
# memory usage: 759.5+ MB

# %%
simplehome_cam2_df.describe()
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# count     850826.000000   850826.000000        8.508260e+05     850826.000000
# mean          98.267421      217.703235        1.630061e+04        157.310067
# std           69.820806      186.657549        2.324521e+04        110.721784
# min            1.000000       60.000000        0.000000e+00          1.000000
# 25%            1.000021       60.000000        4.547474e-13          1.001654
# 50%          113.937651       74.036305        3.333553e+01        190.754000
# 75%          153.322975      399.601699        3.396891e+04        244.793540
# max          438.002839      886.166851        1.738886e+05        505.805302
#
#        MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# count   850826.000000        8.508260e+05     850826.000000   850826.000000
# mean       217.281892        1.798373e+04        451.984966      216.745867
# std        181.888014        2.339461e+04        314.962663      177.097290
# min         60.000000        0.000000e+00          1.000000       60.000000
# 25%         60.000000        1.364242e-12          1.165747       60.000009
# 50%         74.052170        3.720039e+01        589.447259       74.117649
# 75%        407.418216        4.021541e+04        685.369245      418.159054
# max        846.320306        1.731848e+05       1210.948467      709.725273
#
#        MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_radius  \
# count       850826.000000       850826.000000  ...     850826.000000
# mean         19584.994464         4200.983257  ...        126.320362
# std          23637.415247         2918.960456  ...       4190.332407
# min              0.000000            1.000000  ...          0.000000
# 25%              0.000078            2.901582  ...          0.000000
# 50%             39.892104         5781.952998  ...          0.000000
# 75%          45720.413445         6475.322401  ...          0.000000
# max         173077.043447         8946.997229  ...     480808.294900
#
#        HpHp_L0.1_covariance  HpHp_L0.1_pcc  HpHp_L0.01_weight  \
# count         850826.000000  850826.000000      850826.000000
# mean               2.422651       0.000051        1300.955911
# std              556.762383       0.010928        5267.027544
# min           -37601.681020      -0.587497           1.000000
# 25%                0.000000       0.000000           1.000000
# 50%                0.000000       0.000000           1.000000
# 75%                0.000000       0.000000           1.000000
# max            69895.058490       0.956099       29932.352278
#
#        HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  \
# count    850826.000000   850826.000000         850826.000000
# mean        216.236807        0.162011            219.367660
# std         225.507277        4.266169            226.700814
# min          60.000000        0.000000             60.000000
# 25%          60.000000        0.000000             60.000000
# 50%          74.000000        0.000000             74.000000
# 75%         554.000000        0.000000            554.000000
# max         909.000000      220.178576           1278.265351
#
#        HpHp_L0.01_radius  HpHp_L0.01_covariance  HpHp_L0.01_pcc
# count      850826.000000          850826.000000   850826.000000
# mean          166.705960               3.276070       -0.000379
# std          5900.757300            1360.191527        0.026018
# min             0.000000          -68855.092130       -1.137592
# 25%             0.000000               0.000000        0.000000
# 50%             0.000000               0.000000        0.000000
# 75%             0.000000               0.000000        0.000000
# max        479368.980762          143864.110900        1.531981
#
# [8 rows x 115 columns]

# %% [markdown]
# #### 2D scatter Plot

# %%
# SKLearn Library
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
def plot_2d_scatter_plot(df, title):
    X = df.drop(['label','device'], axis=1).values
    y = df['label'].values
    X_std = StandardScaler().fit_transform(X)
    pca = PCA(n_components=2)
    X_pca = pca.fit_transform(X_std)
    
    data_X = X_pca[:,0]
    data_Y = X_pca[:,1]
    data_Z = y
    
    colors = ["#ff0000", "#006600", "#ffff00"]
    # Set your custom color palette
    customPalette = sns.set_palette(sns.color_palette(colors))
    
    sns.set(rc={'figure.figsize':(12,9)})
    sns.scatterplot(x=data_X, y=data_Y, hue=data_Z, palette=customPalette).set_title(title)

# %%
danmini_doorbell_df['label'].value_counts()
# Out:
# mirai     652100
# gafgyt    316650
# benign     49548
# Name: label, dtype: int64

# %%
plot_2d_scatter_plot(danmini_doorbell_df, 'Danmini Door Bell')

# %%
ecobee_thermostat_df['label'].value_counts()
# Out:
# mirai     512133
# gafgyt    310630
# benign     13113
# Name: label, dtype: int64

# %%
plot_2d_scatter_plot(ecobee_thermostat_df, 'Ecobee_Thermostat')

# %%
ennio_doorbell_df['label'].value_counts()
# Out:
# gafgyt    316400
# benign     39100
# Name: label, dtype: int64

# %%
plot_2d_scatter_plot(ennio_doorbell_df,  'Ennio_Doorbell')

# %%
baby_monitor_df['label'].value_counts()
# Out:
# mirai     610714
# gafgyt    312723
# benign    175240
# Name: label, dtype: int64

# %%
plot_2d_scatter_plot(baby_monitor_df, 'Philips_B120N10_Baby_Monitor')

# %%
provision_cam1_df['label'].value_counts()
# Out:
# mirai     436010
# gafgyt    330096
# benign     62154
# Name: label, dtype: int64

# %%
plot_2d_scatter_plot(provision_cam1_df, 'Provision_PT_737E_Security_Camera')

# %%
provision_cam2_df['label'].value_counts()
# Out:
# mirai     429337
# gafgyt    309040
# benign     98514
# Name: label, dtype: int64

# %%
plot_2d_scatter_plot(provision_cam2_df, 'Provision_PT_838_Security_Camera')

# %%
samsung_cam_df['label'].value_counts()
# Out:
# gafgyt    323072
# benign     52150
# Name: label, dtype: int64

# %%
plot_2d_scatter_plot(samsung_cam_df, 'Samsung_SNH_1011_N_Webcam')

# %%
simplehome_cam1_df['label'].value_counts()
# Out:
# mirai     513248
# gafgyt    303223
# benign     46585
# Name: label, dtype: int64

# %%
plot_2d_scatter_plot(simplehome_cam1_df, 'SimpleHome_XCS7_1002_WHT_Security_Camera')

# %%
simplehome_cam2_df['label'].value_counts()
# Out:
# mirai     514860
# gafgyt    316438
# benign     19528
# Name: label, dtype: int64

# %%
plot_2d_scatter_plot(simplehome_cam2_df, 'SimpleHome_XCS7_1003_WHT_Security_Camera')

# %% [markdown]
# #### 3D Scatter Plot

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

plt.rcParams["figure.figsize"] = (12,9)

# %%
def plot_3d_scatter_plot(df, title):
    X = df.drop(['label','device'], axis=1).values
    df["label"] = df["label"].replace({'benign': 0, 'mirai':1, 'gafgyt':2})
    y = df['label'].values
    X_std = StandardScaler().fit_transform(X)
    pca = PCA(n_components=2)
    X_pca = pca.fit_transform(X_std)
    
    
    data_X = X_pca[:,0]
    data_Y = X_pca[:,1]
    data_Z = y

    data = np.column_stack((data_X, data_Y, data_Z))

    benign = mpatches.Patch(color='green', label='Benign')
    mirai = mpatches.Patch(color='red', label='Mirai')
    gafgyt = mpatches.Patch(color='orange', label='Gafgyt')
    handles = [benign, mirai, gafgyt]

    X = data[:,0]
    Y = data[:,1]
    Z = data[:,2]
    
    ax = plt.axes(projection='3d')
    C = ['green' if z == 0 else 'red' if z == 1 else 'orange' for z in Z]
    ax.scatter(X, Y, Z, c = C, cmap='RdYlGn')
    ax.set_title(title);
    plt.legend(handles=handles)
    plt.show()

# %%
plot_3d_scatter_plot(danmini_doorbell_df, 'Danmini Door Bell')

# %%
plot_3d_scatter_plot(ecobee_thermostat_df, 'Ecobee_Thermostat')

# %%
plot_3d_scatter_plot(ennio_doorbell_df,  'Ennio_Doorbell')

# %%
plot_3d_scatter_plot(baby_monitor_df, 'Philips_B120N10_Baby_Monitor')

# %%
plot_3d_scatter_plot(provision_cam1_df, 'Provision_PT_737E_Security_Camera')

# %%
plot_3d_scatter_plot(provision_cam2_df, 'Provision_PT_838_Security_Camera')

# %%
plot_3d_scatter_plot(samsung_cam_df, 'Samsung_SNH_1011_N_Webcam')

# %%
plot_3d_scatter_plot(simplehome_cam1_df, 'SimpleHome_XCS7_1002_WHT_Security_Camera')

# %%
plot_3d_scatter_plot(simplehome_cam2_df, 'SimpleHome_XCS7_1003_WHT_Security_Camera')
